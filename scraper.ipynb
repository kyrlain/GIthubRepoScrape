# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import sqlite3
from sqlalchemy import create_engine
import numpy as np

# %%
url = "https://github.com/trending"

# %%
r = requests.get(url)
soup = BeautifulSoup(r.content, "html.parser")

# %%
def get_data(data):
    df_data = []

    language_soup = data.find_all("article", {"class": "Box-row"})

    for soup in language_soup:
        repo_name = soup.find("h2", {"class": "h3"})
        author = repo_name.a.span.text.strip()[:-2]
        repo = repo_name.a.text.strip().split(" ")[-1]
        description = soup.find("p", {"class": "col-9 color-fg-muted my-1 pr-4"})
        if description:
            description = description.text.strip()
        programming_language = soup.find("span", {"itemprop": "programmingLanguage"})
        if programming_language:
            programming_language = programming_language.text
        star_fork = soup.find_all("a", {"class": "Link Link--muted d-inline-block mr-3"})
        star = star_fork[0].text.strip()
        fork = star_fork[1].text.strip()
        users = soup.find("span", {"class": "d-inline-block mr-3"}).find_all("a")
        users = ", ".join([user.get("href").split("/")[-1] for user in users])
        stars_today = soup.find("span", {"class": "d-inline-block float-sm-right"}).text.strip()
        if stars_today:
            stars_today = stars_today.strip().split(" ")[0]
        
        df_data.append([author, repo, description, programming_language, star, fork, users, stars_today])
    
    return df_data

# %%
# Scraping data of every language
languages = soup.find("div", {"id": "languages-menuitems"}).find_all("a")

data = []
for language in languages:
    programming_language = language.text.strip()
    new_url = language["href"]
    language_url = f"https://github.com{new_url}"

    language_r = requests.get(language_url)
    language_soup = BeautifulSoup(language_r.content, "html.parser")
    
    language_data = get_data(language_soup)
    data.extend(language_data)

# %%
df = pd.DataFrame(data, columns=["Author", "Repo Name", "Description", "Programming Language", "Stars", "Fork", "Top Contributors", "Stars Today"])
display(df)
print(df.info())
# Out:
#               Author                    Repo Name  \
# 0            jwasham  coding-interview-university
# 1     cloudcommunity          Free-Certifications
# 2          jujumilk3        leaked-system-prompts
# 3           khangich   machine-learning-interview
# 4            weeeBox         mobile-system-design
# ...              ...                          ...
# 1108             zml                          zml
# 1109     kristoff-it                         zine
# 1110          hexops                         mach
# 1111      fairyglade                           ly
# 1112   silbinarywolf              zig-android-sdk
#
#                                             Description Programming Language  \
# 0     A complete computer science study plan to beco...                 None
# 1     A curated list of free courses with certificat...                 None
# 2                   Collection of leaked system prompts                 None
# 3     Machine Learning Interviews from FAANG, Snapch...                 None
# 4     A simple framework for mobile system design in...                 None
# ...                                                 ...                  ...
# 1108  Any model. Any hardware. Zero compromise. Buil...                  Zig
# 1109  Fast, Scalable, Flexible Static Site Generator...                  Zig
# 1110                 zig game engine & graphics toolkit                  Zig
# 1111                    display manager with console UI                  Zig
# 1112  This library allows you to setup and build an ...                  Zig
#
#         Stars    Fork                                   Top Contributors  \
# 0     315,614  78,548  jwasham, Anri-Lombard, avizmarlon, esaucedof, ...
# 1      29,885   2,193  karentamrazyan, CloudStudyNet, diogomurta, syk...
# 2       2,519     347  jujumilk3, accupham, OneTop4458, JakubKontra, ...
# 3      10,702   1,734  khangich, liuvivian11, aragorn87, cuongvng, vi...
# 4       4,666     494              weeeBox, AndreiVidrasco, husaynhakeem
# ...       ...     ...                                                ...
# 1108    2,226      80   gwenzek, steeve, Corendos, hugomano, renerocksai
# 1109      892      56  kristoff-it, MFAshby, veggiemonk, Arnau478, kl...
# 1110    3,891     178  alichraghi, iddev5, InKryption, wrench-bot, Pi...
# 1111    5,994     318  AnErrupTion, nullgemm, stlaz, liweitianux, mor...
# 1112       40       3                              silbinarywolf, v3rm0n
#
#      Stars Today
# 0            335
# 1             66
# 2             61
# 3             38
# 4              5
# ...          ...
# 1108           5
# 1109           5
# 1110           4
# 1111           6
# 1112           2
#
# [1113 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1113 entries, 0 to 1112
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Author                1113 non-null   object
#  1   Repo Name             1113 non-null   object
#  2   Description           1068 non-null   object
#  3   Programming Language  1104 non-null   object
#  4   Stars                 1113 non-null   object
#  5   Fork                  1113 non-null   object
#  6   Top Contributors      1113 non-null   object
#  7   Stars Today           1113 non-null   object
# dtypes: object(8)
# memory usage: 69.7+ KB
# None

# %%
# Clean data
df["Stars"] = df["Stars"].str.replace(",","").astype(int)
df["Fork"] = df["Fork"].str.replace(",","").astype(int)
df["Stars Today"] = df["Stars Today"].str.replace(",","").astype(int)
df = df.fillna(value=np.nan)
df["Programming Language"] = df["Programming Language"].fillna("Unknown Language")
display(df)
print(df.info())
# Out:
#               Author                    Repo Name  \
# 0            jwasham  coding-interview-university
# 1     cloudcommunity          Free-Certifications
# 2          jujumilk3        leaked-system-prompts
# 3           khangich   machine-learning-interview
# 4            weeeBox         mobile-system-design
# ...              ...                          ...
# 1108             zml                          zml
# 1109     kristoff-it                         zine
# 1110          hexops                         mach
# 1111      fairyglade                           ly
# 1112   silbinarywolf              zig-android-sdk
#
#                                             Description Programming Language  \
# 0     A complete computer science study plan to beco...     Unknown Language
# 1     A curated list of free courses with certificat...     Unknown Language
# 2                   Collection of leaked system prompts     Unknown Language
# 3     Machine Learning Interviews from FAANG, Snapch...     Unknown Language
# 4     A simple framework for mobile system design in...     Unknown Language
# ...                                                 ...                  ...
# 1108  Any model. Any hardware. Zero compromise. Buil...                  Zig
# 1109  Fast, Scalable, Flexible Static Site Generator...                  Zig
# 1110                 zig game engine & graphics toolkit                  Zig
# 1111                    display manager with console UI                  Zig
# 1112  This library allows you to setup and build an ...                  Zig
#
#        Stars   Fork                                   Top Contributors  \
# 0     315614  78548  jwasham, Anri-Lombard, avizmarlon, esaucedof, ...
# 1      29885   2193  karentamrazyan, CloudStudyNet, diogomurta, syk...
# 2       2519    347  jujumilk3, accupham, OneTop4458, JakubKontra, ...
# 3      10702   1734  khangich, liuvivian11, aragorn87, cuongvng, vi...
# 4       4666    494              weeeBox, AndreiVidrasco, husaynhakeem
# ...      ...    ...                                                ...
# 1108    2226     80   gwenzek, steeve, Corendos, hugomano, renerocksai
# 1109     892     56  kristoff-it, MFAshby, veggiemonk, Arnau478, kl...
# 1110    3891    178  alichraghi, iddev5, InKryption, wrench-bot, Pi...
# 1111    5994    318  AnErrupTion, nullgemm, stlaz, liweitianux, mor...
# 1112      40      3                              silbinarywolf, v3rm0n
#
#       Stars Today
# 0             335
# 1              66
# 2              61
# 3              38
# 4               5
# ...           ...
# 1108            5
# 1109            5
# 1110            4
# 1111            6
# 1112            2
#
# [1113 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1113 entries, 0 to 1112
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Author                1113 non-null   object
#  1   Repo Name             1113 non-null   object
#  2   Description           1068 non-null   object
#  3   Programming Language  1113 non-null   object
#  4   Stars                 1113 non-null   int64
#  5   Fork                  1113 non-null   int64
#  6   Top Contributors      1113 non-null   object
#  7   Stars Today           1113 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 69.7+ KB
# None

# %%
# Loading dataframe to CSV
df.to_csv("github_table.csv", index=False)

# %%
# Connecting and uploading to SQLite database
on = sqlite3.connect("github.db")
engine = create_engine('sqlite:///github.db', echo=False)
df.to_sql('githubtable', con=engine, if_exists='replace', index=False)
# Out:
# 1113

# %%
con = sqlite3.connect("github.db")
cur = con.cursor()
query = """
        SELECT * 
        FROM githubtable
        """
df = pd.read_sql_query(query, con)
display(df)
# Out:
#               Author                    Repo Name  \
# 0            jwasham  coding-interview-university
# 1     cloudcommunity          Free-Certifications
# 2          jujumilk3        leaked-system-prompts
# 3           khangich   machine-learning-interview
# 4            weeeBox         mobile-system-design
# ...              ...                          ...
# 1108             zml                          zml
# 1109     kristoff-it                         zine
# 1110          hexops                         mach
# 1111      fairyglade                           ly
# 1112   silbinarywolf              zig-android-sdk
#
#                                             Description Programming Language  \
# 0     A complete computer science study plan to beco...     Unknown Language
# 1     A curated list of free courses with certificat...     Unknown Language
# 2                   Collection of leaked system prompts     Unknown Language
# 3     Machine Learning Interviews from FAANG, Snapch...     Unknown Language
# 4     A simple framework for mobile system design in...     Unknown Language
# ...                                                 ...                  ...
# 1108  Any model. Any hardware. Zero compromise. Buil...                  Zig
# 1109  Fast, Scalable, Flexible Static Site Generator...                  Zig
# 1110                 zig game engine & graphics toolkit                  Zig
# 1111                    display manager with console UI                  Zig
# 1112  This library allows you to setup and build an ...                  Zig
#
#        Stars   Fork                                   Top Contributors  \
# 0     315614  78548  jwasham, Anri-Lombard, avizmarlon, esaucedof, ...
# 1      29885   2193  karentamrazyan, CloudStudyNet, diogomurta, syk...
# 2       2519    347  jujumilk3, accupham, OneTop4458, JakubKontra, ...
# 3      10702   1734  khangich, liuvivian11, aragorn87, cuongvng, vi...
# 4       4666    494              weeeBox, AndreiVidrasco, husaynhakeem
# ...      ...    ...                                                ...
# 1108    2226     80   gwenzek, steeve, Corendos, hugomano, renerocksai
# 1109     892     56  kristoff-it, MFAshby, veggiemonk, Arnau478, kl...
# 1110    3891    178  alichraghi, iddev5, InKryption, wrench-bot, Pi...
# 1111    5994    318  AnErrupTion, nullgemm, stlaz, liweitianux, mor...
# 1112      40      3                              silbinarywolf, v3rm0n
#
#       Stars Today
# 0             335
# 1              66
# 2              61
# 3              38
# 4               5
# ...           ...
# 1108            5
# 1109            5
# 1110            4
# 1111            6
# 1112            2
#
# [1113 rows x 8 columns]

# %%
con.close()

# %%
con = sqlite3.connect("github.db")
cur = con.cursor()

# %%
# Top Repo Today
query = """
        SELECT *
        FROM githubtable
        ORDER BY Stars DESC
        LIMIT 10
        """
df = pd.read_sql_query(query, con)
display(df)
# Out:
#           Author                    Repo Name  \
# 0        jwasham  coding-interview-university
# 1  kamranahmedse            developer-roadmap
# 2           ossu             computer-science
# 3           twbs                    bootstrap
# 4        flutter                      flutter
# 5      jackfrued              Python-100-Days
# 6              f      awesome-chatgpt-prompts
# 7        angular                      angular
# 8     open-webui                   open-webui
# 9         neovim                       neovim
#
#                                          Description Programming Language  \
# 0  A complete computer science study plan to beco...     Unknown Language
# 1  Interactive roadmaps, guides and other educati...           TypeScript
# 2  🎓 Path to a free self-taught education in Comp...                 HTML
# 3  The most popular HTML, CSS, and JavaScript fra...                  MDX
# 4  Flutter makes it easy and fast to build beauti...                 Dart
# 5                                Python - 100天从新手到大师     Jupyter Notebook
# 6  This repo includes ChatGPT prompt curation to ...           JavaScript
# 7                 Deliver web apps with confidence 🚀           TypeScript
# 8  User-friendly AI Interface (Supports Ollama, O...           JavaScript
# 9    Vim-fork focused on extensibility and usability           Vim Script
#
#     Stars   Fork                                   Top Contributors  \
# 0  315614  78548  jwasham, Anri-Lombard, avizmarlon, esaucedof, ...
# 1  315258  40951  kamranahmedse, dansholds, arikchakma, github-a...
# 2  178456  22606  ericdouglas, waciumawanjohi, joshmhanson, mkgh...
# 3  172233  79069           mdo, cvrebert, XhmikosR, fat, dependabot
# 4  169896  28401  engine-flutter-autoroll, jonahwilliams, abarth...
# 5  164470  53531  jackfrued, MathDance, geekya215, jankeromnes, ...
# 6  123371  16518       f, iuzn, fengkiej, JonathanDn, developer-acc
# 7   97578  26138  gkalpak, petebacondarwin, devversion, crisbeto...
# 8   90923  11470  tjbck, cheahjs, jannikstdl, michaelpoluektov, ...
# 9   88887   6045         zeertzjq, justinmk, janlazo, bfredl, ZyX-I
#
#    Stars Today
# 0          335
# 1          337
# 2          162
# 3           16
# 4           35
# 5           74
# 6           70
# 7           34
# 8          197
# 9           41

# %%
# Top Starred Repo Today
query = """
        SELECT *
        FROM githubtable
        ORDER BY "Stars Today" DESC
        LIMIT 10
        """
df = pd.read_sql_query(query, con)
display(df)
# Out:
#           Author                    Repo Name  \
# 0      microsoft                   markitdown
# 1      microsoft                       BitNet
# 2     anthropics                      courses
# 3  kamranahmedse            developer-roadmap
# 4        jwasham  coding-interview-university
# 5     jumpserver                   jumpserver
# 6         Byaidu             PDFMathTranslate
# 7      drawdb-io                       drawdb
# 8      microsoft      ai-agents-for-beginners
# 9     open-webui                   open-webui
#
#                                          Description Programming Language  \
# 0  Python tool for converting files and office do...               Python
# 1        Official inference framework for 1-bit LLMs                  C++
# 2                    Anthropic's educational courses     Jupyter Notebook
# 3  Interactive roadmaps, guides and other educati...           TypeScript
# 4  A complete computer science study plan to beco...     Unknown Language
# 5  JumpServer is an open-source Privileged Access...               Python
# 6  PDF scientific paper translation with preserve...               Python
# 7  Free, simple, and intuitive online database di...           JavaScript
# 8       10 Lessons to Get Started Building AI Agents     Jupyter Notebook
# 9  User-friendly AI Interface (Supports Ollama, O...           JavaScript
#
#     Stars   Fork                                   Top Contributors  \
# 0   52723   2604  afourney, gagb, sugatoray, PetrAPConsulting, l...
# 1   16486   1186  potassiummmm, younesbelkada, tsong-ms, dawnmsg...
# 2   10472    952        Colt, alexalbertt, rainlee, elie, maggie-vo
# 3  315258  40951  kamranahmedse, dansholds, arikchakma, github-a...
# 4  315614  78548  jwasham, Anri-Lombard, avizmarlon, esaucedof, ...
# 5   27213   5459    ibuler, BaiJiangJie, feng626, fit2bot, xuxinwen
# 6   21624   1832  Byaidu, awwaawwa, hellofinch, reycn, tastelike...
# 7   27706   1953  1ilit, dependabot, haecheonlee, FelixZY, picimako
# 8   16627   4140  koreyspace, leestott, ShivamGoyal03, jt-216, a...
# 9   90923  11470  tjbck, cheahjs, jannikstdl, michaelpoluektov, ...
#
#    Stars Today
# 0          980
# 1          730
# 2          383
# 3          337
# 4          335
# 5          285
# 6          272
# 7          256
# 8          234
# 9          197

# %%
# Top Programming Languages
query = """
        SELECT "Programming Language",
            SUM(Stars) AS "Total Stars",
            SUM(Fork) AS "Total Forks"
        FROM githubtable
        GROUP BY "Programming Language"
        ORDER BY "Total Stars" DESC
        LIMIT 10
        """
df = pd.read_sql_query(query, con)
display(df)
# Out:
#   Programming Language  Total Stars  Total Forks
# 0           TypeScript       534627        80027
# 1                 Java       515181       163765
# 2                   Go       482644        55969
# 3           JavaScript       451351        79680
# 4                  C++       418626        69526
# 5     Unknown Language       404413        95927
# 6                 Rust       396316        27135
# 7     Jupyter Notebook       382267       119697
# 8                 HTML       350302        86798
# 9                  MDX       336030       113811

# %%
# Closing the connection
con.close()
